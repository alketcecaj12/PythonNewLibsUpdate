# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.data import iris_data
from mlxtend.plotting import plot_decision_regions

# Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = SVC(random_state=0, probability=True)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[2, 1, 1], voting='soft')

# Loading some example data
X, y = iris_data()
X = X[:,[0, 2]]

# Plotting Decision Regions

gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression',
          'Random Forest',
          'RBF kernel SVM',
          'Ensemble']

for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1],
                         repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y,
                                clf=clf, legend=2)
    plt.title(lab)

plt.show()
# Out:
# /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (0.23.3)
# Requirement already satisfied: scipy>=1.2.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (3.8.0)
# Requirement already satisfied: joblib>=0.13.2 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=1.3.1->mlxtend) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Users/alket/miniconda3/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
